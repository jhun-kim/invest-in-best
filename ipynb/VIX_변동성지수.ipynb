# %%
from pykrx import stock
import pandas as pd
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

# %%
# KS11 (KOSPI 지수), 2017년~현재
df = fdr.DataReader('KS11', '2017')
df
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2017-01-02  2026.16  2022.23  2031.79  2015.68  229880000.0 -0.0001
# 2017-01-03  2043.97  2034.31  2044.07  2028.47  268130000.0  0.0088
# 2017-01-04  2045.64  2046.29  2046.29  2040.61  371490000.0  0.0008
# 2017-01-05  2041.95  2045.52  2046.50  2039.49  541340000.0 -0.0018
# 2017-01-06  2049.12  2048.11  2051.84  2045.66  455350000.0  0.0035
# ...             ...      ...      ...      ...          ...     ...
# 2022-05-20  2639.29  2605.78  2641.68  2605.38  755650000.0  0.0181
# 2022-05-23  2647.38  2651.63  2653.87  2634.29  644200000.0  0.0031
# 2022-05-24  2605.87  2638.94  2646.99  2605.87  851240000.0 -0.0157
# 2022-05-25  2617.22  2621.75  2630.17  2602.94     698940.0  0.0044
# 2022-05-26  2612.45  2616.99  2641.91  2602.01     583600.0 -0.0018
#
# [1327 rows x 6 columns]

# %%
c_vix = pd.read_csv('C:/Users/jhp07/OneDrive/문서/프로젝트1/csv/CBOE Volatility Index 내역.csv')
c_vix.sort_values('날짜', ascending=True, inplace=True, ignore_index=True)

# %%
k_vix = pd.read_csv('../csv/KOSPI Volatility 내역.csv')
k_vix.sort_values('날짜', ascending=True, inplace=True, ignore_index=True)

# %%
c_vix
# Out:
#                  날짜     종가     오픈     고가     저가 거래량    변동 %
# 0     2017년 01월 03일  12.85  14.07  14.07  12.85   -  -8.48%
# 1     2017년 01월 04일  11.85  12.78  12.80  11.63   -  -7.78%
# 2     2017년 01월 05일  11.67  11.96  12.09  11.40   -  -1.52%
# 3     2017년 01월 06일  11.32  11.70  11.74  10.98   -  -3.00%
# 4     2017년 01월 09일  11.56  11.71  12.08  11.46   -   2.12%
# ...             ...    ...    ...    ...    ...  ..     ...
# 1355  2022년 05월 10일  32.99  33.66  34.84  32.24   -  -5.06%
# 1356  2022년 05월 11일  32.56  32.87  34.39  30.69   -  -1.30%
# 1357  2022년 05월 12일  31.77  33.74  34.76  31.70   -  -2.43%
# 1358  2022년 05월 13일  28.87  31.09  31.20  28.78   -  -9.13%
# 1359  2022년 05월 16일  27.47  30.01  30.23  27.36   -  -4.85%
#
# [1360 rows x 7 columns]

# %%
k_vix
# Out:
#                  날짜     종가     오픈     고가     저가 거래량     변동 %
# 0     2017년 01월 02일  11.68  12.28  12.30  11.68   -    1.48%
# 1     2017년 01월 03일  11.24  11.66  11.66  11.21   -   -3.77%
# 2     2017년 01월 04일  10.90  11.19  11.20  10.90   -   -3.02%
# 3     2017년 01월 05일  11.12  10.92  11.20  10.79   -    2.02%
# 4     2017년 01월 06일  11.00  11.02  11.03  10.76   -   -1.08%
# ...             ...    ...    ...    ...    ...  ..      ...
# 1314  2022년 05월 10일  22.11  23.05  24.09  21.85   -    3.37%
# 1315  2022년 05월 11일  21.10  21.76  22.19  21.02   -   -4.57%
# 1316  2022년 05월 12일  22.72  21.99  23.06  20.65   -    7.68%
# 1317  2022년 05월 13일  19.69  21.11  21.25  19.69   -  -13.34%
# 1318  2022년 05월 16일  20.27  19.94  20.88  19.94   -    2.95%
#
# [1319 rows x 7 columns]

# %%
plt.plot(df['Close'])

plt.show()

# %%
plt.plot(k_vix['종가'])    
plt.show()

# %%
plt.plot(c_vix['종가'])

plt.show()

# %%
fig = plt.figure(figsize=(15,10))

plt.subplot(311)
plt.plot(df['Close'])

plt.subplot(312)
plt.plot(k_vix['종가'])               

plt.subplot(313)
plt.plot(c_vix['종가'])

plt.show()
