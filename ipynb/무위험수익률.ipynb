# %%
import pandas as pd

# %%
rf_df = pd.read_csv('/content/drive/MyDrive/프로젝트1 데이터/DGS1.csv')

# %%
rf_df
# Out:
#             DATE  DGS1
# 0     2017-01-03  0.89
# 1     2017-01-04  0.87
# 2     2017-01-05  0.83
# 3     2017-01-06  0.85
# 4     2017-01-09  0.82
# ...          ...   ...
# 1399  2022-05-16  2.07
# 1400  2022-05-17  2.16
# 1401  2022-05-18  2.16
# 1402  2022-05-19  2.11
# 1403  2022-05-20  2.07
#
# [1404 rows x 2 columns]

# %%
a = rf_df['DGS1'].tolist()

# %%
a
# Out:
# ['0.89',
#  '0.87',
#  '0.83',
#  '0.85',
#  '0.82',
#  '0.82',
#  '0.82',
#  '0.81',
#  '0.82',
#  '.',
#  '0.80',
#  '0.82',
#  '0.83',
#  '0.82',
#  '0.79',
#  '0.81',
#  '0.82',
#  '0.82',
#  '0.82',
#  '0.81',
#  '0.84',
#  '0.83',
#  '0.84',
#  '0.82',
#  '0.79',
#  '0.80',
#  '0.79',
#  '0.80',
#  '0.81',
#  '0.82',
#  '0.84',
#  '0.86',
#  '0.82',
#  '0.82',
#  '.',
#  '0.83',
#  '0.82',
#  '0.81',
#  '0.80',
#  '0.81',
#  '0.88',
#  '0.92',
#  '0.98',
#  '0.98',
#  '0.97',
#  '1.02',
#  '1.03',
#  '1.04',
#  '1.03',
#  '1.06',
#  '1.06',
#  '1.02',
#  '1.01',
#  '1.00',
#  '1.01',
#  '1.00',
#  '0.99',
#  '0.99',
#  '1.00',
#  '1.00',
#  '1.03',
#  '1.04',
#  '1.03',
#  '1.03',
#  '1.02',
#  '1.03',
#  '1.03',
#  '1.05',
#  '1.08',
#  '1.07',
#  '1.05',
#  '1.04',
#  '1.03',
#  '.',
#  '1.04',
#  '1.02',
#  '1.02',
#  '1.01',
#  '0.99',
#  '1.03',
#  '1.09',
#  '1.07',
#  '1.06',
#  '1.07',
#  '1.09',
#  '1.08',
#  '1.10',
#  '1.11',
#  '1.10',
#  '1.12',
#  '1.14',
# ...
