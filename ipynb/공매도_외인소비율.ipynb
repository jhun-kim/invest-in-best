# %%
# !pip install pykrx

# %%
from pykrx import stock
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get_shorting_status_by_date(시작날짜, 종료날짜, 종목상장번호)

short_df = stock.get_shorting_status_by_date("20170101", "20220516", "005930")
 
short_df
# Out:
#                거래량     잔고수량         거래대금          잔고금액
# 날짜
# 2017-01-02    4911   107079   8865743000  193277595000
# 2017-01-03   15278   116897  27831715000  213220128000
# 2017-01-04   33406   126156  60529759000  228090048000
# 2017-01-05   15645   121885  28021510000  216711530000
# 2017-01-06    7276   126403  13186910000  228789430000
# ...            ...      ...          ...           ...
# 2022-05-10  446750  8192241  29316107400  538230233700
# 2022-05-11  466835  8412794  30771801500  552720565800
# 2022-05-12  684098  8491529  44625777600  551100232100
# 2022-05-13  858607  7879526  56870659400  523988479000
# 2022-05-16  436791  8013302  29052681800  531281922600
#
# [1319 rows x 4 columns]

# %%
price_df = stock.get_market_ohlcv("20170101", "20220516", "005930")
if price_df.empty :
    print(None)
else:
    print(price_df)
# Out:
#                시가     고가     저가     종가       거래량
# 날짜
# 2017-01-02  35980  36240  35880  36100     93012
# 2017-01-03  36280  36620  36020  36480    147153
# 2017-01-04  36500  36520  36100  36160    159435
# 2017-01-05  36060  36060  35540  35560    219349
# 2017-01-06  36180  36440  36040  36200    177619
# ...           ...    ...    ...    ...       ...
# 2022-05-10  65900  66300  65300  65700  17235605
# 2022-05-11  65500  66300  65200  65700  12330920
# 2022-05-12  65200  65500  64900  64900  16414188
# 2022-05-13  65300  66700  65200  66500  14551536
# 2022-05-16  67100  67400  66100  66300  11937555
#
# [1319 rows x 5 columns]

# %%
plt.plot(short_df['잔고수량'])
plt.show()

# %%
plt.plot(price_df['종가'])
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.plot(short_df['잔고수량'])               


plt.subplot(2, 1, 2)         
plt.plot(price_df['종가'])


plt.show()
